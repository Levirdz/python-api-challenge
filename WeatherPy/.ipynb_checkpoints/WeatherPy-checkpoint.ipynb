# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_key import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Performing API Calls

# %%
# Creating empty lists to hold data
city_name = []
city_temp = []
city_lat = []
city_lon = []
city_hmdty = []
city_wndspd = []
city_cldns = []
city_country = []
city_maxtemp = []
date = []

# %%
# Defining base url and data units
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric" # I want my temp in Celsius and Wind Speed in meters/second

# Setting count variables 
record = 0 
query_set = 1 

print("Beginning Data Retrieval")
print("----------------------------")

# Requesting data for each city 
for city in cities: 
    
    query_url = f"{base_url}appid={weather_api_key}&units={units}&q="
    
    data = requests.get(query_url + city).json()
    
    if record < 50:
        record += 1
    
    else: 
        query_set += 1
        record = 1
        
    print(f"Processing Record {record} of Set {query_set} | {city}")

    try: 
        
        city_name.append(data["name"])
        city_temp.append(data["main"]["temp"])
        city_lat.append(data["coord"]["lat"])
        city_lon.append(data["coord"]["lon"])
        city_hmdty.append(data["main"]["humidity"])
        city_wndspd.append(data["wind"]["speed"])
        city_cldns.append(data["clouds"]["all"])
        city_country.append(data["sys"]["country"])
        city_maxtemp.append(data["main"]["temp_max"])
        date.append(data["dt"])
                                                
    except: 
        
        print("City not found. Skipping...")
        
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | tukrah
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | berlevag
# Processing Record 8 of Set 1 | axim
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | ponta do sol
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | minot
# Processing Record 15 of Set 1 | vostok
# Processing Record 16 of Set 1 | portland
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | verkh-usugli
# Processing Record 20 of Set 1 | yeppoon
# Processing Record 21 of Set 1 | victoria
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | cairns
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | nago
# Processing Record 26 of Set 1 | boditi
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | coxim
# Processing Record 29 of Set 1 | victor harbor
# Processing Record 30 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 1 | tagusao
# Processing Record 32 of Set 1 | alofi
# Processing Record 33 of Set 1 | victoria point
# Processing Record 34 of Set 1 | torbay
# Processing Record 35 of Set 1 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 1 | empa
# City not found. Skipping...
# Processing Record 37 of Set 1 | hobbs
# Processing Record 38 of Set 1 | constitucion
# Processing Record 39 of Set 1 | longyan
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | taft
# Processing Record 42 of Set 1 | wiang sa
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 36 of Set 4 | diebougou
# Processing Record 37 of Set 4 | koslan
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | kangaatsiaq
# Processing Record 40 of Set 4 | naryan-mar
# Processing Record 41 of Set 4 | carros
# Processing Record 42 of Set 4 | marsh harbour
# Processing Record 43 of Set 4 | nikolskoye
# Processing Record 44 of Set 4 | alabaster
# Processing Record 45 of Set 4 | potamia
# Processing Record 46 of Set 4 | saint-joseph
# Processing Record 47 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 48 of Set 4 | khandyga
# Processing Record 49 of Set 4 | kachug
# Processing Record 50 of Set 4 | ponerihouen
# Processing Record 1 of Set 5 | padang
# Processing Record 2 of Set 5 | buchanan
# Processing Record 3 of Set 5 | terrace
# Processing Record 4 of Set 5 | ormara
# Processing Record 5 of Set 5 | la ronge
# Processing Record 6 of Set 5 | sitka
# Processing Record 7 of Set 5 | boundiali
# Processing Record 8 of Set 5 | matay
# Processing Record 9 of Set 5 | haines junction
# Processing Record 10 of Set 5 | birao
# Processing Record 11 of Set 5 | lakota
# Processing Record 12 of Set 5 | dores do indaia
# Processing Record 13 of Set 5 | taoudenni
# Processing Record 14 of Set 5 | olinda
# Processing Record 15 of Set 5 | port hardy
# Processing Record 16 of Set 5 | marsa matruh
# Processing Record 17 of Set 5 | tartagal
# Processing Record 18 of Set 5 | yulara
# Processing Record 19 of Set 5 | sao joao da barra
# Processing Record 20 of Set 5 | emerald
# Processing Record 21 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 5 | eureka
# Processing Record 23 of Set 5 | hermanus
# Processing Record 24 of Set 5 | faya
# Processing Record 25 of Set 5 | quatre cocos
# Processing Record 26 of Set 5 | tanda
# Processing Record 27 of Set 5 | maceio
# Processing Record 28 of Set 5 | keroka
# Processing Record 29 of Set 5 | ust-ilimsk
# Processing Record 30 of Set 5 | keti bandar
# Processing Record 31 of Set 5 | cam pha
# City not found. Skipping...
# Processing Record 32 of Set 5 | douglas
# Processing Record 33 of Set 5 | cidreira
# Processing Record 34 of Set 5 | tiksi
# Processing Record 35 of Set 5 | borova
# Processing Record 36 of Set 5 | saint-francois
# Processing Record 37 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 5 | mossendjo
# Processing Record 39 of Set 5 | udachnyy
# Processing Record 40 of Set 5 | srednekolymsk
# Processing Record 41 of Set 5 | richards bay
# Processing Record 42 of Set 5 | surt
# Processing Record 43 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 5 | kalagarh
# Processing Record 45 of Set 5 | salinas
# Processing Record 46 of Set 5 | dzaoudzi
# Processing Record 47 of Set 5 | santa maria
# Processing Record 48 of Set 5 | beloha
# Processing Record 49 of Set 5 | fortuna
# Processing Record 50 of Set 5 | kitimat
# Processing Record 1 of Set 6 | saint george
# Processing Record 2 of Set 6 | jieshi
# Processing Record 3 of Set 6 | kargasok
# Processing Record 4 of Set 6 | aitape
# Processing Record 5 of Set 6 | cabo san lucas
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 6 | adrar
# Processing Record 9 of Set 6 | krasnoselkup
# Processing Record 10 of Set 6 | bakel
# Processing Record 11 of Set 6 | iqaluit
# Processing Record 12 of Set 6 | ionia
# Processing Record 13 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 6 | fort nelson
# Processing Record 16 of Set 6 | chokurdakh
# Processing Record 17 of Set 6 | quelimane
# Processing Record 18 of Set 6 | monrovia
# Processing Record 19 of Set 6 | touros
# Processing Record 20 of Set 6 | hays
# Processing Record 21 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 22 of Set 6 | ziro
# Processing Record 23 of Set 6 | broome
# Processing Record 24 of Set 6 | katangli
# Processing Record 25 of Set 6 | inta
# Processing Record 26 of Set 6 | safranbolu
# Processing Record 27 of Set 6 | awbari
# Processing Record 28 of Set 6 | mana
# Processing Record 29 of Set 6 | henderson
# Processing Record 30 of Set 6 | dahanu
# Processing Record 31 of Set 6 | tailai
# Processing Record 32 of Set 6 | aykhal
# Processing Record 33 of Set 6 | ballarat
# Processing Record 34 of Set 6 | fairbanks
# Processing Record 35 of Set 6 | zhanakorgan
# Processing Record 36 of Set 6 | sault sainte marie
# Processing Record 37 of Set 6 | ulaanbaatar
# Processing Record 38 of Set 6 | vanimo
# Processing Record 39 of Set 6 | abonnema
# Processing Record 40 of Set 6 | codrington
# Processing Record 41 of Set 6 | staryy nadym
# Processing Record 42 of Set 6 | sinnamary
# Processing Record 43 of Set 6 | zyryanka
# Processing Record 44 of Set 6 | hay river
# Processing Record 45 of Set 6 | artyom
# Processing Record 46 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 6 | arcoverde
# Processing Record 48 of Set 6 | mersing
# Processing Record 49 of Set 6 | kuryk
# Processing Record 50 of Set 6 | dingle
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | bathsheba
# Processing Record 3 of Set 7 | sisimiut
# Processing Record 4 of Set 7 | bloemfontein
# Processing Record 5 of Set 7 | andenes
# Processing Record 6 of Set 7 | susangerd
# Processing Record 7 of Set 7 | lodja
# Processing Record 8 of Set 7 | bandarbeyla
# Processing Record 9 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 7 | arkul
# Processing Record 11 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 12 of Set 7 | sangar
# Processing Record 13 of Set 7 | alta floresta
# Processing Record 14 of Set 7 | chuy
# Processing Record 15 of Set 7 | nome
# Processing Record 16 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record
# Processing Record 8 of Set 10 | slave lake
# Processing Record 9 of Set 10 | dembi dolo
# Processing Record 10 of Set 10 | tocopilla
# Processing Record 11 of Set 10 | bam
# Processing Record 12 of Set 10 | north bend
# Processing Record 13 of Set 10 | maragogi
# Processing Record 14 of Set 10 | vila franca do campo
# Processing Record 15 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 17 of Set 10 | atar
# Processing Record 18 of Set 10 | gunjur
# Processing Record 19 of Set 10 | tuatapere
# Processing Record 20 of Set 10 | ji-parana
# City not found. Skipping...
# Processing Record 21 of Set 10 | colares
# Processing Record 22 of Set 10 | shelburne
# Processing Record 23 of Set 10 | minab
# Processing Record 24 of Set 10 | katete
# Processing Record 25 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 10 | yumen
# Processing Record 27 of Set 10 | antalaha
# Processing Record 28 of Set 10 | katha
# City not found. Skipping...
# Processing Record 29 of Set 10 | kruisfontein
# Processing Record 30 of Set 10 | comodoro rivadavia
# Processing Record 31 of Set 10 | kieta
# Processing Record 32 of Set 10 | paytug
# City not found. Skipping...
# Processing Record 33 of Set 10 | high level
# Processing Record 34 of Set 10 | ewo
# Processing Record 35 of Set 10 | salisbury
# Processing Record 36 of Set 10 | sardarshahr
# Processing Record 37 of Set 10 | qobustan
# Processing Record 38 of Set 10 | ramhormoz
# Processing Record 39 of Set 10 | tabuk
# Processing Record 40 of Set 10 | praia da vitoria
# Processing Record 41 of Set 10 | olafsvik
# Processing Record 42 of Set 10 | glendive
# Processing Record 43 of Set 10 | tilichiki
# Processing Record 44 of Set 10 | gotemba
# Processing Record 45 of Set 10 | kobryn
# Processing Record 46 of Set 10 | champerico
# Processing Record 47 of Set 10 | leh
# Processing Record 48 of Set 10 | brae
# Processing Record 49 of Set 10 | tottori
# Processing Record 50 of Set 10 | inuvik
# Processing Record 1 of Set 11 | west plains
# Processing Record 2 of Set 11 | new glasgow
# Processing Record 3 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 11 | nelson bay
# Processing Record 5 of Set 11 | chapais
# Processing Record 6 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 11 | ilulissat
# Processing Record 8 of Set 11 | zaplyusye
# City not found. Skipping...
# Processing Record 9 of Set 11 | sanmenxia
# Processing Record 10 of Set 11 | farap
# Processing Record 11 of Set 11 | stekolnyy
# City not found. Skipping...
# Processing Record 12 of Set 11 | chuncheng
# Processing Record 13 of Set 11 | veraval
# Processing Record 14 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 15 of Set 11 | chukhloma
# Processing Record 16 of Set 11 | farah
# Processing Record 17 of Set 11 | felipe carrillo puerto
# Processing Record 18 of Set 11 | puerto penasco
# Processing Record 19 of Set 11 | motala
# Processing Record 20 of Set 11 | agua dulce
# Processing Record 21 of Set 11 | port hedland
# Processing Record 22 of Set 11 | concarneau
# Processing Record 23 of Set 11 | kenai
# Processing Record 24 of Set 11 | shingu
# Processing Record 25 of Set 11 | rio grande
# Processing Record 26 of Set 11 | sommerda
# Processing Record 27 of Set 11 | koroni
# Processing Record 28 of Set 11 | piterka
# Processing Record 29 of Set 11 | zhetybay
# City not found. Skipping...
# Processing Record 30 of Set 11 | the pas
# Processing Record 31 of Set 11 | lorengau
# Processing Record 32 of Set 11 | belaya gora
# Processing Record 33 of Set 11 | egvekinot
# Processing Record 34 of Set 11 | patea
# Processing Record 35 of Set 11 | elko
# Processing Record 36 of Set 11 | porto novo
# Processing Record 37 of Set 11 | wanxian
# Processing Record 38 of Set 11 | sydney
# Processing Record 39 of Set 11 | kawalu
# Processing Record 40 of Set 11 | filadelfia
# Processing Record 41 of Set 11 | hefei
# Processing Record 42 of Set 11 | maridi
# Processing Record 43 of Set 11 | alice springs
# Processing Record 44 of Set 11 | kloulklubed
# Processing Record 45 of Set 11 | kang
# Processing Record 46 of Set 11 | sambava
# Processing Record 47 of Set 11 | whyalla
# Processing Record 48 of Set 11 | arosa
# Processing Record 49 of Set 11 | makakilo city
# Processing Record 50 of Set 11 | vardo
# Processing Record 1 of Set 12 | ganzhou
# Processing Record 2 of Set 12 | tianpeng
# Processing Record 3 of Set 12 | puerto leguizamo
# Processing Record 4 of Set 12 | lyuban
# Processing Record 5 of Set 12 | luderitz
# Processing Record 6 of Set 12 | sierra vista
# Processing Record 7 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 8 of Set 12 | murray bridge
# Processing Record 9 of Set 12 | pathein
# Processing Record 10 of Set 12 | port blair
# Processing Record 11 of Set 12 | moron
# Processing Record 12 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 12 | guiratinga
# Processing Record 14 of Set 12 | kiama
# Processing Record 15 of Set 12 | mabaruma
# Processing Record 16 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 17 of Set 12 | seydi
# Processing Record 18 of Set 12 | teguise
# Processing Record 19 of Set 12 | borodino
# Processing Record 20 of Set 12 | cap-aux-meules
# Processing Record 21 of Set 12 | glubokoe
# City not found. Skipping...
# Processing Record 22 of Set 12 | bodden town
# Processing Record 23 of Set 12 | hamilton
# Processing Record 24 of Set 12 | asfi
# Processing Record 25 of Set 12 | friesenheim
# Processing Record 26 of Set 12 | manokwari
# Processing Record 27 of Set 12 | paka
# Processing Record 28 of Set 12 | nipawin
# Processing Record 29 of Set 12 | zaozerne
# Processing Record 30 of Set 12 | zhob
# Processing Record 31 of Set 12 | buenaventura
# Processing Record 32 of Set 12 | tsaratanana
# Processing Record 33 of Set 12 | denpasar
# Processing Record 34 of Set 12 | la primavera
# Processing Record 35 of Set 12 | buturlino
# Processing Record 36 of Set 12 | amposta
# Processing Record 37 of Set 12 | kanigoro
# Processing Record 38 of Set 12 | praya
# Processing Record 39 of Set 12 | sistranda
# Processing Record 40 of Set 12 | isla mujeres
# Processing Record 41 of Set 12 | tessalit
# Processing Record 42 of Set 12 | tralee
# Processing Record 43 of Set 12 | tadpatri
# Processing Record 44 of Set 12 | rocha
# Processing Record 45 of Set 12 | raudeberg
# Processing Record 46 of Set 12 | makhinjauri
# Processing Record 47 of Set 12 | qaqortoq
# Processing Record 48 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 49 of Set 12 | sayyan
# Processing Record 50 of Set 12 | yazman
# Processing Record 1 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 13 | sarapul
# Processing Record 3 of Set 13 | rorvik
# Processing Record 4 of Set 13 | husavik
# Processing Record 5 of Set 13 | ngunguru
# Processing Record 6 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 7 of Set 13 | ostersund
# Processing Record 8 of Set 13 | mayumba
# Processing Record 9 of Set 13 | mushabani
# Processing Record 10 of Set 13 | los llanos de aridane
# Processing Record 11 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 12 of Set 13 | nouakchott
# Processing Record 13 of Set 13 | ahipara
# Processing Record 14 of Set 13 | synya
# Processing Record 15 of Set 13 | klaksvik
# Processing Record 16 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 13 | sassandra
# Processing Record 18 of Set 13 | barahona
# Processing Record 19 of Set 13 | warqla
# City not found. Skipping...
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %% [markdown]
# Displaying the DataFrame

# %%
# Creating pandas dataframe
weather_df = pd.DataFrame({"City": city_name, 
                          "Country": city_country, 
                          "Date": date, 
                          "Latitude": city_lat, 
                          "Longitude": city_lon, 
                          "Temperature": city_temp, 
                          "Max. Temp.": city_maxtemp, 
                           "Humidity": city_hmdty, 
                           "Cloudiness": city_cldns, 
                           "Wind Speed": city_wndspd})

weather_df
# Out:
#                        City Country        Date  Latitude  Longitude  \
# 0               Clyde River      CA  1600065995     70.47     -68.59
# 1                   Rikitea      PF  1600065995    -23.12    -134.97
# 2                    Tūkrah      LY  1600065995     32.53      20.58
# 3              Punta Arenas      CL  1600065996    -53.15     -70.92
# 4                    Barrow      US  1600065996     71.29    -156.79
# ..                      ...     ...         ...       ...        ...
# 550                 Ahipara      NZ  1600066165    -35.17     173.17
# 551                   Synya      RU  1600066165     65.37      58.04
# 552                Klaksvík      FO  1600066165     62.23      -6.59
# 553               Sassandra      CI  1600066166      4.95      -6.08
# 554  Santa Cruz de Barahona      DO  1600066166     18.21     -71.10
#
#      Temperature  Max. Temp.  Humidity  Cloudiness  Wind Speed
# 0           1.00        1.00        83          90        1.00
# 1          23.16       23.16        84           0        6.33
# 2          28.44       28.44        53          15        6.16
# 3           6.83        7.00        65         100        9.30
# 4           4.00        4.00        93          90        6.70
# ..           ...         ...       ...         ...         ...
# 550        12.43       12.43        73          62        4.88
# 551        10.32       10.32        89         100        4.68
# 552         8.00        8.00       100          89        2.60
# 553        24.03       24.03        92          97        3.96
# 554        25.93       25.93        77          21        0.73
#
# [555 rows x 10 columns]

# %% [markdown]
# Exporting city data to csv file

# %%
# Saving data as csv file in the selected folder
weather_df.to_csv("Output Data/weather_data.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.

# %% [markdown]
# Using the "max" function to find out if there are cities with humidity > 100%

# %%
weather_df["Humidity"].max()

# There are no cities above 100% humidity
# Out:
# 100

# %% [markdown]
# Getting the indices of cities above 100% humidity (just to confirm)

# %%
humidity_df = weather_df.loc[weather_df["Humidity"] > 100]
humidity_df.index

# Result is blank because there are no cities above 100% humidity, skipping this step as instructed
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# ## Plotting the Data

# %%
# Setting variables to start plotting
latitude = weather_df["Latitude"]
longitude = weather_df["Longitude"]
temperature = weather_df["Temperature"]
humidity = weather_df["Humidity"]
cloudiness = weather_df["Cloudiness"]
windspeed = weather_df["Wind Speed"]

# Converting date to the appropiate format 
analysis_date = pd.to_datetime("today")
analysis_date = analysis_date.strftime("%d/%m/%y")

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Generating scatter plot
plt.scatter(latitude, temperature, marker = "o", color = "orange", edgecolors = "tomato")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Temperature [°C] @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Temperature [°C]")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_temp.png")
plt.show()

# %% [markdown]
# ###### Observations:
# * The nearer to the equator, the higher the temperature.
# * The max. temperatures registered are found in the 20-40 latitude range.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Generating scatter plot
plt.scatter(latitude, humidity, marker = "o", color = "springgreen", edgecolors = "seagreen")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Humidity (%) @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_hmdty.png")
plt.show()

# %% [markdown]
# ###### Observations:
# * There seems to be a higher humidity level in the northern hemisphere.
# * Most cities' humidity values are above 60%.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Generating scatter plot
plt.scatter(latitude, cloudiness, marker = "o", color = "aquamarine", edgecolors = "c")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Cloudiness (%) @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_cldns.png")
plt.show()

# %% [markdown]
# ###### Observations:
# * There are different cloudiness values along the whole range of latitudes, so correlation must be close to 0.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Generating scatter plot
plt.scatter(latitude, windspeed, marker = "o", color = "gold", edgecolors = "darkgoldenrod")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Wind Speed [m/s] @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed [m/s]")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_wndspd.png")
plt.show()

# %% [markdown]
# ###### Observations:
# * Wind speed ranges from 0 to 14 m/s with no clear pattern vs any latitude.
# * Correlation once again seems very low on this one.

# %% [markdown]
# ## Linear Regression

# %%
# Creating a function to plot the linear regression 

def lr (x, y, ax = None): 
    
    ax = ax
    slope, intercept, rvalue, pvalue, stderr = linregress(x, y)
    print(f"The r-squared value is: {rvalue ** 2}")
    
    regress_values = slope * x + intercept
     
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
     
    ax.plot(x, regress_values, color = "darkslateblue")

    return ax, line_eq

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hem = weather_df.loc[weather_df["Latitude"] >= 0,]
south_hem = weather_df.loc[weather_df["Latitude"] < 0,]

# %%
# Creating variables for each hemisphere
north_latitudes = north_hem["Latitude"]
north_maxtemp = north_hem["Max. Temp."]
north_hmdty = north_hem["Humidity"]
north_cldns = north_hem["Cloudiness"]
north_wndspd = north_hem["Wind Speed"]

south_latitudes = south_hem["Latitude"]
south_maxtemp = south_hem["Max. Temp."]
south_hmdty = south_hem["Humidity"]
south_cldns = south_hem["Cloudiness"]
south_wndspd = south_hem["Wind Speed"]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Generating line regression and printing line_eq on the plot
fig, ax = plt.subplots()
ax, line_eq = lr(north_latitudes, north_maxtemp, ax)
plt.annotate(line_eq, (0, 0), fontsize = 14, color = "crimson")

# Generating scatter plot
plt.scatter(north_latitudes, north_maxtemp, marker = "o", color = "orange", edgecolors = "tomato")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Max. Temperature [°C] in the Northern Hemisphere @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Max. Temperature [°C]")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_maxtemp_north_hem.png")
plt.show()
# Out:
# The r-squared value is: 0.631005642605995

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Generating line regression and printing line_eq on the plot
fig, ax = plt.subplots()
ax, line_eq = lr(south_latitudes, south_maxtemp, ax)
plt.annotate(line_eq, (-55, 30), fontsize = 14, color = "crimson")

# Generating scatter plot
plt.scatter(south_latitudes, south_maxtemp, marker = "o", color = "orange", edgecolors = "tomato")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Max. Temperature [°C] in the Southern Hemisphere @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Max. Temperature [°C]")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_maxtemp_south_hem.png")
plt.show()
# Out:
# The r-squared value is: 0.5312882314314019

# %% [markdown]
# ###### Observations:
# * We can confirm that the closer to latitude 0 (equator) the higher the temperature recording.
# * Correlation is pretty clear once you analyze temperature per hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Generating line regression and printing line_eq on the plot
fig, ax = plt.subplots()
ax, line_eq = lr(north_latitudes, north_hmdty, ax)
plt.annotate(line_eq, (50, 10), fontsize = 14, color = "crimson")

# Generating scatter plot
plt.scatter(north_latitudes, north_hmdty, marker = "o", color = "springgreen", edgecolors = "seagreen")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Humidity (%) in the Northern Hemisphere @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_hmdty_north_hem.png")
plt.show()
# Out:
# The r-squared value is: 0.007032884882560741

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Generating line regression and printing line_eq on the plot
fig, ax = plt.subplots()
ax, line_eq = lr(south_latitudes, south_hmdty, ax)
plt.annotate(line_eq, (-55, 20), fontsize = 14, color = "crimson")

# Generating scatter plot
plt.scatter(south_latitudes, south_hmdty, marker = "o", color = "springgreen", edgecolors = "seagreen")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Humidity (%) in the Southern Hemisphere @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_hmdty_south_hem.png")
plt.show()
# Out:
# The r-squared value is: 0.004364309661851986

# %% [markdown]
# ###### Observations:
# * Northern hemisphere is clearly more humid than the southern hemisphere.
# * We can confirm there is little to no correlation on latitude vs humidity in the world.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Generating line regression and printing line_eq on the plot
fig, ax = plt.subplots()
ax, line_eq = lr(north_latitudes, north_cldns, ax)
plt.annotate(line_eq, (50, 30), fontsize = 14, color = "crimson")

# Generating scatter plot
plt.scatter(north_latitudes, north_cldns, marker = "o", color = "aquamarine", edgecolors = "c")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Cloudiness (%) in the Northern Hemisphere @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_cldns_north_hem.png")
plt.show()
# Out:
# The r-squared value is: 0.0022633220426747044

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Generating line regression and printing line_eq on the plot
fig, ax = plt.subplots()
ax, line_eq = lr(south_latitudes, south_cldns, ax)
plt.annotate(line_eq, (-55, 13), fontsize = 14, color = "crimson")

# Generating scatter plot
plt.scatter(south_latitudes, south_cldns, marker = "o", color = "aquamarine", edgecolors = "c")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Cloudiness (%) in the Southern Hemisphere @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_cldns_south_hem.png")
plt.show()
# Out:
# The r-squared value is: 0.004959678271701897

# %% [markdown]
# ###### Observations:
# * Northern hemisphere seems to be more cloudy than southern hemisphere, humidity might be a reason to explain this.
# * We can confirm there is little to no correlation on latitude vs cloudiness in the world.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Generating line regression and printing line_eq on the plot
fig, ax = plt.subplots()
ax, line_eq = lr(north_latitudes, north_wndspd, ax)
plt.annotate(line_eq, (0, 12), fontsize = 14, color = "crimson")

# Generating scatter plot
plt.scatter(north_latitudes, north_wndspd, marker = "o", color = "gold", edgecolors = "darkgoldenrod")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Wind Speed [m/s] in the Northern Hemisphere @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed [m/s]")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_wndspd_north_hem.png")
plt.show()
# Out:
# The r-squared value is: 0.028319001079984186

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Generating line regression and printing line_eq on the plot
fig, ax = plt.subplots()
ax, line_eq = lr(south_latitudes, south_wndspd, ax)
plt.annotate(line_eq, (-55, 11), fontsize = 14, color = "crimson")

# Generating scatter plot
plt.scatter(south_latitudes, south_wndspd, marker = "o", color = "gold", edgecolors = "darkgoldenrod")

# Setting title, labels, limits, etc. 
plt.title(f"Latitude vs. Wind Speed [m/s] in the Southern Hemisphere @ ({analysis_date})", size = 14)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed [m/s]")
plt.grid()

# Saving file in my output folder as png
plt.savefig("Output Data/lat_vs_wndspd_south_hem.png")
plt.show()
# Out:
# The r-squared value is: 0.054580699645000036

# %% [markdown]
# ###### Observations:
# * There are more wind speed readings on the northern hemisphere which might simply indicate that the world is more populated on its northern hemisphere.
# * We can confirm there is little to no correlation on latitude vs wind speed in the world.
